# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:01<00:00, 3.65MB/s]

# %%
results = model.predict(
    source = r"C:\Users\pranj\OneDrive\Desktop\INTERNSHIP\OPEN_CV\VIDEOS\video_ex1.avi",
    save = True,
    imgsz = 640,
    conf = 0.5,
    classes = [0] #detect only 'person'
)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/795) C:\Users\pranj\OneDrive\Desktop\INTERNSHIP\OPEN_CV\VIDEOS\video_ex1.avi: 480x640 3 persons, 264.7ms
# video 1/1 (frame 2/795) C:\Users\pranj\OneDrive\Desktop\INTERNSHIP\OPEN_CV\VIDEOS\video_ex1.avi: 480x640 3 persons, 185.0ms
# video 1/1 (frame 3/795) C:\Users\pranj\OneDrive\Desktop\INTERNSHIP\OPEN_CV\VIDEOS\video_ex1.avi: 480x640 3 persons, 181.4ms
# ...
